# %%
import json
import smtplib
from email.mime.multipart import MIMEMultipart
from email.mime.text import MIMEText
from email.mime.image import MIMEImage
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

def read_config(file_path):
    with open(file_path, 'r') as config_file:
        config_data = json.load(config_file)
    return config_data

def send_email(subject, body, sender, recipients, password, html_content, inline_images=None):
    msg = MIMEMultipart()
    msg['Subject'] = subject
    msg['From'] = sender
    msg['To'] = ', '.join(recipients)

    if body:
        msg.attach(MIMEText(body, 'plain'))

    if html_content:
        msg.attach(MIMEText(html_content, 'html'))

    if inline_images:
        for image_cid, image_path in inline_images.items():
            with open(image_path, 'rb') as fp:
                img = MIMEImage(fp.read())
                img.add_header('Content-ID', f'<{image_cid}>')
                msg.attach(img)

    with smtplib.SMTP_SSL('smtp.gmail.com', 465) as smtp_server:
        smtp_server.login(sender, password)
        smtp_server.sendmail(sender, recipients, msg.as_string())
    print("Message sent!")

def generate_html_content():
    # Enhanced HTML content for the newsletter
    html_content = """
    <html>
    <head>
        <style>
            body {{
                font-family: Arial, sans-serif;
                line-height: 1.6;
                margin: 0;
                padding: 0;
                background-color: #f4f4f4;
            }}
            .container {{
                width: 80%;
                margin: auto;
                padding: 20px;
                background-color: #ffffff;
                border-radius: 10px;
                box-shadow: 0 2px 5px rgba(0,0,0,0.1);
            }}
            .header {{
                background-color: #4CAF50;
                color: #ffffff;
                padding: 20px 0;
                text-align: center;
                border-top-left-radius: 10px;
                border-top-right-radius: 10px;
            }}
            h1 {{
                margin-top: 20px;
                color: #333333;
                text-align: center;
            }}
            p {{
                margin-bottom: 15px;
                color: #555555;
                padding: 0 20px;
            }}
            ul {{
                list-style-type: none;
                padding: 0 20px;
                color: #555555;
            }}
            li {{
                margin-bottom: 10px;
                color: #555555;
            }}
            .footer {{
                margin-top: 20px;
                text-align: center;
                color: #777777;
            }}
        </style>
    </head>
    <body>
        <div class="container">
            <div class="header">
                <h1>Weekly Portfolio Update</h1>
            </div>
            <p>Dear Investors,</p>
            <p>We are pleased to present this week's portfolio update. Below are the highlights:</p>
            <ul>
                <li><strong style="color: #4CAF50;">Performance:</strong> Our portfolio continues to show strong performance, outperforming market benchmarks.</li>
                <li><strong style="color: #4CAF50;">New Investments:</strong> We have made strategic investments in promising companies across various sectors.</li>
                <li><strong style="color: #4CAF50;">Portfolio Diversification:</strong> We maintain a well-diversified portfolio to mitigate risks and capitalize on opportunities.</li>
            </ul>
            <p>Thank you for your continued trust and support.</p>
            <p>Best regards,</p>
            <p>Your Portfolio Management Team</p>
            <div class="footer">
                <p>This email was sent to you as a part of our investor communication. If you wish to unsubscribe or have any queries, please contact us.</p>
            </div>
        </div>
    </body>
    </html>
    """
    return html_content

def main():
    config = read_config('/content/Mailer Configuration File.JSON')
    sender = config['sender']
    recipients = ["xflamesdaily@gmail.com", "ami.desai1101@gmail.com"]
    password = config['password']
    subject = "Daily Stock Report"
    body = "Please find below the daily stock report."

    # Construct the HTML content for the newsletter
    html_content = generate_html_content()

    # Send email with HTML content
    send_email(subject, body, sender, recipients, password, html_content)

if __name__ == "__main__":
    main()
# Out:
# Message sent!

# %%
import json
import smtplib
from email.mime.multipart import MIMEMultipart
from email.mime.text import MIMEText
from email.mime.image import MIMEImage

def read_config(file_path):
    with open(file_path, 'r') as config_file:
        config_data = json.load(config_file)
    return config_data

def send_email(subject, body, sender, recipients, password, html_content, inline_images=None):
    msg = MIMEMultipart()
    msg['Subject'] = subject
    msg['From'] = sender
    msg['To'] = ', '.join(recipients)

    if body:
        msg.attach(MIMEText(body, 'plain'))

    if html_content:
        msg.attach(MIMEText(html_content, 'html'))

    if inline_images:
        for image_cid, image_path in inline_images.items():
            with open(image_path, 'rb') as fp:
                img = MIMEImage(fp.read())
                img.add_header('Content-ID', f'<{image_cid}>')
                msg.attach(img)

    with smtplib.SMTP_SSL('smtp.gmail.com', 465) as smtp_server:
        smtp_server.login(sender, password)
        smtp_server.sendmail(sender, recipients, msg.as_string())
    print("Message sent!")

def generate_html_content():
    # Enhanced HTML content for the newsletter
    html_content = """
    <html>
    <head>
        <style>
            body {{
                font-family: Arial, sans-serif;
                line-height: 1.6;
                margin: 0;
                padding: 0;
                background-color: #f4f4f4;
            }}
            .container {{
                width: 80%;
                margin: auto;
                padding: 20px;
                background-color: #ffffff;
                border-radius: 10px;
                box-shadow: 0 2px 5px rgba(0,0,0,0.1);
            }}
            .header {{
                background-color: #4CAF50;
                color: #ffffff;
                padding: 20px 0;
                text-align: center;
                border-top-left-radius: 10px;
                border-top-right-radius: 10px;
            }}
            h1 {{
                margin-top: 20px;
                color: #333333;
                text-align: center;
            }}
            p {{
                margin-bottom: 15px;
                color: #555555;
                padding: 0 20px;
            }}
            ul {{
                list-style-type: none;
                padding: 0 20px;
                color: #555555;
            }}
            li {{
                margin-bottom: 10px;
                color: #555555;
            }}
            .footer {{
                margin-top: 20px;
                text-align: center;
                color: #777777;
            }}
            table {{
                width: 100%;
                border-collapse: collapse;
                margin-top: 20px;
            }}
            th, td {{
                border: 1px solid #dddddd;
                text-align: left;
                padding: 8px;
            }}
            th {{
                background-color: #4CAF50;
                color: #ffffff;
            }}
            .table-title {{
                text-align: center;
                background-color: #4CAF50;
                color: #ffffff;
                padding: 10px;
            }}
        </style>
    </head>
    <body>
        <div class="container">
            <div class="header">
                <h1>Weekly Portfolio Update</h1>
            </div>
            <p>Dear Investors,</p>
            <p>We are pleased to present this week's portfolio update. Below are the highlights:</p>
            <ul>
                <li><strong style="color: #4CAF50;">Performance:</strong> Our portfolio continues to show strong performance, outperforming market benchmarks.</li>
                <li><strong style="color: #4CAF50;">New Investments:</strong> We have made strategic investments in promising companies across various sectors.</li>
                <li><strong style="color: #4CAF50;">Portfolio Diversification:</strong> We maintain a well-diversified portfolio to mitigate risks and capitalize on opportunities.</li>
            </ul>
            <p>Thank you for your continued trust and support.</p>
            <h2 class="table-title">Top 5 Best Performing Stocks</h2>
            <table>
                <thead>
                    <tr>
                        <th>Stock</th>
                        <th>High</th>
                        <th>Close</th>
                        <th>Low</th>
                        <th>Open</th>
                        <th>Volume</th>
                    </tr>
                </thead>
                <tbody>
                    <tr>
                        <td style="border: 1px solid #dddddd;">Stock 1</td>
                        <td style="border: 1px solid #dddddd;">888</td>
                        <td style="border: 1px solid #dddddd;">777</td>
                        <td style="border: 1px solid #dddddd;">666</td>
                        <td style="border: 1px solid #dddddd;">555</td>
                        <td style="border: 1px solid #dddddd;">444</td>
                    </tr>
                    <tr>
                        <td style="border: 1px solid #dddddd;">Stock 2</td>
                        <td style="border: 1px solid #dddddd;">777</td>
                        <td style="border: 1px solid #dddddd;">666</td>
                        <td style="border: 1px solid #dddddd;">555</td>
                        <td style="border: 1px solid #dddddd;">444</td>
                        <td style="border: 1px solid #dddddd;">333</td>
                    </tr>
                    <tr>
                        <td style="border: 1px solid #dddddd;">Stock 3</td>
                        <td style="border: 1px solid #dddddd;">666</td>
                        <td style="border: 1px solid #dddddd;">555</td>
                        <td style="border: 1px solid #dddddd;">444</td>
                        <td style="border: 1px solid #dddddd;">333</td>
                        <td style="border: 1px solid #dddddd;">222</td>
                    </tr>
                    <tr>
                        <td style="border: 1px solid #dddddd;">Stock 4</td>
                        <td style="border: 1px solid #dddddd;">555</td>
                        <td style="border: 1px solid #dddddd;">444</td>
                        <td style="border: 1px solid #dddddd;">333</td>
                        <td style="border: 1px solid #dddddd;">222</td>
                        <td style="border: 1px solid #dddddd;">111</td>
                    </tr>
                    <tr>
                        <td style="border: 1px solid #dddddd;">Stock 5</td>
                        <td style="border: 1px solid #dddddd;">444</td>
                        <td style="border: 1px solid #dddddd;">333</td>
                        <td style="border: 1px solid #dddddd;">222</td>
                        <td style="border: 1px solid #dddddd;">111</td>
                        <td style="border: 1px solid #dddddd;">000</td>
                    </tr>
                </tbody>
            </table>
            <p>Best regards,</p>
            <p>Your Portfolio Management Team</p>
            <div class="footer">
                <p>This email was sent to you as a part of our investor communication. If you wish to unsubscribe or have any queries, please contact us.</p>
            </div>
        </div>
    </body>
    </html>
    """
    return html_content

def main():
    config = read_config('/content/Mailer Configuration File.JSON')
    sender = config['sender']
    recipients = ["xflamesdaily@gmail.com", "ami.desai1101@gmail.com"]
    password = config['password']
    subject = "Daily Stock Report"
    body = "Please find below the daily stock report."

    # Construct the HTML content for the newsletter
    html_content = generate_html_content()

    # Send email with HTML content
    send_email(subject, body, sender, recipients, password, html_content)

if __name__ == "__main__":
    main()
# Out:
# Message sent!

# %%
import json
import smtplib
from email.mime.multipart import MIMEMultipart
from email.mime.text import MIMEText
from email.mime.image import MIMEImage

def read_config(file_path):
    with open(file_path, 'r') as config_file:
        config_data = json.load(config_file)
    return config_data

def send_email(subject, body, sender, recipients, password, html_content, inline_images=None):
    msg = MIMEMultipart()
    msg['Subject'] = subject
    msg['From'] = sender
    msg['To'] = ', '.join(recipients)

    if body:
        msg.attach(MIMEText(body, 'plain'))

    if html_content:
        msg.attach(MIMEText(html_content, 'html'))

    if inline_images:
        for image_cid, image_path in inline_images.items():
            with open(image_path, 'rb') as fp:
                img = MIMEImage(fp.read())
                img.add_header('Content-ID', f'<{image_cid}>')
                msg.attach(img)

    with smtplib.SMTP_SSL('smtp.gmail.com', 465) as smtp_server:
        smtp_server.login(sender, password)
        smtp_server.sendmail(sender, recipients, msg.as_string())
    print("Message sent!")

def generate_html_content():
    # Enhanced HTML content for the newsletter
    html_content = """
    <html>
<head>
    <style>
        body {
            font-family: Arial, sans-serif;
            line-height: 1.6;
            margin: 0;
            padding: 0;
            background-color: #f4f4f4;
        }

        .container {
            width: 80%;
            margin: auto;
            padding: 20px;
            background-color: #ffffff;
            border-radius: 10px;
            box-shadow: 0 2px 5px rgba(0,0,0,0.1);
        }

        .header {
            background-color: #4CAF50;
            color: #ffffff;
            padding: 20px 0;
            text-align: center;
            border-top-left-radius: 10px;
            border-top-right-radius: 10px;
        }

        h1 {
            margin-top: 20px;
            color: #333333;
            text-align: center;
        }

        p {
            margin-bottom: 15px;
            color: #555555;
            padding: 0 20px;
        }

        ul {
            list-style-type: none;
            padding: 0 20px;
            color: #555555;
        }

        li {
            margin-bottom: 10px;
            color: #555555;
        }

        .footer {
            margin-top: 20px;
            text-align: center;
            color: #777777;
        }

        table {
            width: 100%;
            border-collapse: collapse;
            margin-top: 20px;
        }

        th, td {
            border: 1px solid #dddddd;
            text-align: left;
            padding: 8px;
        }

        th {
            background-color: #4CAF50;
            color: #ffffff;
        }

        .table-title {
            text-align: center;
            background-color: #4CAF50;
            color: #ffffff;
            padding: 10px;
        }

        .table-container {
            border: 2px solid #4CAF50; /* Blue color */
            border-radius: 10px;
            padding: 10px;
            margin-top: 20px;
            overflow-x: auto; /* Enable horizontal scrolling if needed */
        }
    </style>
</head>
<body>
    <div class="container">
        <div class="header">
            <h1>Weekly Portfolio Update</h1>
        </div>
        <p>Dear Investors,</p>
        <p>We are pleased to present this week's portfolio update. Below are the highlights:</p>
        <ul>
            <li><strong style="color: #4CAF50;">Performance:</strong> Our portfolio continues to show strong performance, outperforming market benchmarks.</li>
            <li><strong style="color: #4CAF50;">New Investments:</strong> We have made strategic investments in promising companies across various sectors.</li>
            <li><strong style="color: #4CAF50;">Portfolio Diversification:</strong> We maintain a well-diversified portfolio to mitigate risks and capitalize on opportunities.</li>
        </ul>
        <p>Thank you for your continued trust and support.</p>
        <h2 class="table-title">Top 5 Best Performing Stocks</h2>
        <div class="table-container">
            <table>
                <thead>
                    <tr>
                        <th>Stock</th>
                        <th>High</th>
                        <th>Close</th>
                        <th>Low</th>
                        <th>Open</th>
                        <th>Volume</th>
                    </tr>
                </thead>
                <tbody>
                    <tr>
                        <td style="border: 1px solid #dddddd;">Stock 1</td>
                        <td style="border: 1px solid #dddddd;">888</td>
                        <td style="border: 1px solid #dddddd;">777</td>
                        <td style="border: 1px solid #dddddd;">666</td>
                        <td style="border: 1px solid #dddddd;">555</td>
                        <td style="border: 1px solid #dddddd;">444</td>
                    </tr>
                    <tr>
                        <td style="border: 1px solid #dddddd;">Stock 2</td>
                        <td style="border: 1px solid #dddddd;">777</td>
                        <td style="border: 1px solid #dddddd;">666</td>
                        <td style="border: 1px solid #dddddd;">555</td>
                        <td style="border: 1px solid #dddddd;">444</td>
                        <td style="border: 1px solid #dddddd;">333</td>
                    </tr>
                    <tr>
                        <td style="border: 1px solid #dddddd;">Stock 3</td>
                        <td style="border: 1px solid #dddddd;">666</td>
                        <td style="border: 1px solid #dddddd;">555</td>
                        <td style="border: 1px solid #dddddd;">444</td>
                        <td style="border: 1px solid #dddddd;">333</td>
                        <td style="border: 1px solid #dddddd;">222</td>
                    </tr>
                    <tr>
                        <td style="border: 1px solid #dddddd;">Stock 4</td>
                        <td style="border: 1px solid #dddddd;">555</td>
                        <td style="border: 1px solid #dddddd;">444</td>
                        <td style="border: 1px solid #dddddd;">333</td>
                        <td style="border: 1px solid #dddddd;">222</td>
                        <td style="border: 1px solid #dddddd;">111</td>
                    </tr>
                    <tr>
                        <td style="border: 1px solid #dddddd;">Stock 5</td>
                        <td style="border: 1px solid #dddddd;">444</td>
                        <td style="border: 1px solid #dddddd;">333</td>
                        <td style="border: 1px solid #dddddd;">222</td>
                        <td style="border: 1px solid #dddddd;">111</td>
                        <td style="border: 1px solid #dddddd;">000</td>
                    </tr>
                </tbody>
            </table>
        </div>
        <p>Best regards,</p>
        <p>Your Portfolio Management Team</p>
        <div class="footer">
            <p>This email was sent to you as a part of our investor communication. If you wish to unsubscribe or have any queries, please contact us.</p>
        </div>
    </div>
</body>
</html>
    """
    return html_content

def main():
    config = read_config('/content/Mailer Configuration File.JSON')
    sender = config['sender']
    recipients = ["xflamesdaily@gmail.com", "ami.desai1101@gmail.com"]
    password = config['password']
    subject = "Daily Stock Report"
    body = "Please find below the daily stock report."

    # Construct the HTML content for the newsletter
    html_content = generate_html_content()

    # Send email with HTML content
    send_email(subject, body, sender, recipients, password, html_content)

if __name__ == "__main__":
    main()
# Out:
# Message sent!
